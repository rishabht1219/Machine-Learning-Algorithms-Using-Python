# %%
import pandas as pd
import keras
import numpy as np
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv(r"C:\Users\BDA\Downloads\2_5404680059514520677.csv")

# %%
X = df.iloc[:,0:4]

# %%
X.head()

# %%
X= np.array(X)

# %%
Y = df.iloc[:,5]

# %%
Y
# Out:
# 0        6051
# 1       12102
# 2       18153
# 3       24204
# 4       22187
# 5        8068
# 6       14119
# 7       20170
# 8       18153
# 9       24204
# 10      10085
# 11      16136
# 12      14119
# 13      20170
# 14      26221
# 15      12102
# 16      10085
# 17      16136
# 18      22187
# 19      28238
# 20       6051
# 21      12102
# 22      18153
# 23      24204
# 24      22187
# 25       8068
# 26      14119
# 27      20170
# 28      18153
# 29      24204
#         ...
# 971     14126
# 972     20180
# 973     18162
# 974     24216
# 975     10090
# 976     16144
# 977     14126
# 978     20180
# 979     26234
# 980     12108
# 981     10090
# 982     16144
# 983     22198
# 984     28252
# 985      6054
# 986     12108
# 987     18162
# 988     24216
# 989     22198
# 990      8072
# 991     14126
# 992     20180
# 993     18162
# 994     24216
# 995     10090
# 996     16144
# 997     14126
# 998     20180
# 999     26234
# 1000    12108
# ...

# %%
Y= np.array(Y)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

# %%
model = Sequential()
model.add(Dense(4, input_dim=4, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From C:\Users\BDA\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\BDA\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\BDA\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
#compile the keras model
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\BDA\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#fit the keras model in the dataset
model.fit(x_train, y_train, epochs=300, batch_size=4)
# Out:
# WARNING:tensorflow:From C:\Users\BDA\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\BDA\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/300
# 800/800 [==============================] - 2s 2ms/step - loss: 299788457.2400
# Epoch 2/300
# 800/800 [==============================] - 0s 402us/step - loss: 228114120.0800
# Epoch 3/300
# 800/800 [==============================] - 0s 513us/step - loss: 121268558.5519
# Epoch 4/300
# 800/800 [==============================] - 0s 550us/step - loss: 52475603.6700
# Epoch 5/300
# 800/800 [==============================] - 0s 495us/step - loss: 39538642.1369
# Epoch 6/300
# 800/800 [==============================] - 0s 405us/step - loss: 39058503.0850
# Epoch 7/300
# ...

# %%
x_train.shape
# Out:
# (800, 4)

# %%
np.reshape(np.array([1, 1, 4, 2017,]),[1,4])
# Out:
# array([[   1,    1,    4, 2017]])

# %%
new =np.array([[1, 1, 4, 2017]])

# %%
Y_pred = model.predict(new)

# %%
Y_pred
# Out:
# array([[11790.408]], dtype=float32)
